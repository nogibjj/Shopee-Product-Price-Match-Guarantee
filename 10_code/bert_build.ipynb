# %%
from shutil import copyfile
import re
import os
import numpy as np
import pandas as pd
import random
import math
import matplotlib.pyplot as plt
import tensorflow as tf
tf.gfile = tf.io.gfile
import warnings
warnings.simplefilter('ignore')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
#from tensorflow.keras import backend as K
# copyfile(src = "../input/shopee-external-models/tokenization.py", dst = "../working/tokenization.py")
#from bert_tensorflow import tokenization
import tokenization
from bert import tokenization
import tensorflow_hub as hub

# %%
# Configuration
EPOCHS = 25
BATCH_SIZE = 32
# Seed
SEED = 123
# Verbosity
VERBOSE = 1
LR = 0.00001
# Function to seed everything
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    
def read_and_preprocess():
    df = pd.read_csv('/workspaces/Shopee-Price-Match-Guarantee/00_source_data/train_text_processed.csv')
    tmp = df.groupby(['label_group'])['posting_id'].unique().to_dict()
    df['matches'] = df['label_group'].map(tmp)
    df['matches'] = df['matches'].apply(lambda x: ' '.join(x))
    encoder = LabelEncoder()
    df['label_group'] = encoder.fit_transform(df['label_group'])
    N_CLASSES = df['label_group'].nunique()
    print(f'We have {N_CLASSES} classes')
    x_train, x_val, y_train, y_val = train_test_split(df[['title']], df['label_group'], shuffle = True, stratify = df['label_group'], random_state = SEED, test_size = 0.33)
    return df, N_CLASSES, x_train, x_val, y_train, y_val

# Return tokens, masks and segments from a text array or series
def bert_encode(texts, tokenizer, max_len=512):
    all_tokens = []
    all_masks = []
    all_segments = []
    
    for text in texts:
        text = tokenizer.tokenize(text)
            
        text = text[:max_len-2]
        input_sequence = ["[CLS]"] + text + ["[SEP]"]
        pad_len = max_len - len(input_sequence)
        
        tokens = tokenizer.convert_tokens_to_ids(input_sequence)
        tokens += [0] * pad_len
        pad_masks = [1] * len(input_sequence) + [0] * pad_len
        segment_ids = [0] * max_len
        
        all_tokens.append(tokens)
        all_masks.append(pad_masks)
        all_segments.append(segment_ids)
    
    return np.array(all_tokens), np.array(all_masks), np.array(all_segments)


# Arcmarginproduct class keras layer
class ArcMarginProduct(tf.keras.layers.Layer):
    '''
    Implements large margin arc distance.

    Reference:
        https://arxiv.org/pdf/1801.07698.pdf
        https://github.com/lyakaap/Landmark2019-1st-and-3rd-Place-Solution/
            blob/master/src/modeling/metric_learning.py
    '''
    def __init__(self, n_classes, s=30, m=0.50, easy_margin=False,
                 ls_eps=0.0, **kwargs):

        super(ArcMarginProduct, self).__init__(**kwargs)

        self.n_classes = n_classes
        self.s = s
        self.m = m
        self.ls_eps = ls_eps
        self.easy_margin = easy_margin
        self.cos_m = tf.math.cos(m)
        self.sin_m = tf.math.sin(m)
        self.th = tf.math.cos(math.pi - m)
        self.mm = tf.math.sin(math.pi - m) * m

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'n_classes': self.n_classes,
            's': self.s,
            'm': self.m,
            'ls_eps': self.ls_eps,
            'easy_margin': self.easy_margin,
        })
        return config

    def build(self, input_shape):
        super(ArcMarginProduct, self).build(input_shape[0])

        self.W = self.add_weight(
            name='W',
            shape=(int(input_shape[0][-1]), self.n_classes),
            initializer='glorot_uniform',
            dtype='float32',
            trainable=True,
            regularizer=None)

    def call(self, inputs):
        X, y = inputs
        y = tf.cast(y, dtype=tf.int32)
        cosine = tf.matmul(
            tf.math.l2_normalize(X, axis=1),
            tf.math.l2_normalize(self.W, axis=0)
        )
        sine = tf.math.sqrt(1.0 - tf.math.pow(cosine, 2))
        phi = cosine * self.cos_m - sine * self.sin_m
        if self.easy_margin:
            phi = tf.where(cosine > 0, phi, cosine)
        else:
            phi = tf.where(cosine > self.th, phi, cosine - self.mm)
        one_hot = tf.cast(
            tf.one_hot(y, depth=self.n_classes),
            dtype=cosine.dtype
        )
        if self.ls_eps > 0:
            one_hot = (1 - self.ls_eps) * one_hot + self.ls_eps / self.n_classes

        output = (one_hot * phi) + ((1.0 - one_hot) * cosine)
        output *= self.s
        return output

# Function to build bert model
def build_bert_model(bert_layer, max_len = 512):
    
    margin = ArcMarginProduct(
            n_classes = N_CLASSES, 
            s = 30, 
            m = 0.5, 
            name='head/arc_margin', 
            dtype='float32'
            )
    
    input_word_ids = tf.keras.layers.Input(shape=(max_len,), dtype=tf.int32, name="input_word_ids")
    input_mask = tf.keras.layers.Input(shape=(max_len,), dtype=tf.int32, name="input_mask")
    segment_ids = tf.keras.layers.Input(shape=(max_len,), dtype=tf.int32, name="segment_ids")
    label = tf.keras.layers.Input(shape = (), name = 'label')

    _, sequence_output = bert_layer([input_word_ids, input_mask, segment_ids])
    clf_output = sequence_output[:, 0, :]
    x = margin([clf_output, label])
    output = tf.keras.layers.Softmax(dtype='float32')(x)
    model = tf.keras.models.Model(inputs = [input_word_ids, input_mask, segment_ids, label], outputs = [output])
    model.compile(optimizer = tf.keras.optimizers.Adam(lr = LR),
                  loss = [tf.keras.losses.SparseCategoricalCrossentropy()],
                  metrics = [tf.keras.metrics.SparseCategoricalAccuracy()])
    return model

def load_train_and_evaluate(x_train, x_val, y_train, y_val):
    seed_everything(SEED)
    # Load BERT from the Tensorflow Hub
    module_url = "https://tfhub.dev/tensorflow/bert_en_uncased_L-24_H-1024_A-16/1"
    bert_layer = hub.KerasLayer(module_url, trainable = True)
    vocab_file = bert_layer.resolved_object.vocab_file.asset_path.numpy()
    do_lower_case = bert_layer.resolved_object.do_lower_case.numpy()
    print(type(vocab_file))
    tokenizer = tokenization.FullTokenizer(vocab_file, do_lower_case)
    x_train = bert_encode(x_train['title'].values, tokenizer, max_len = 70)
    x_val = bert_encode(x_val['title'].values, tokenizer, max_len = 70)
    y_train = y_train.values
    y_val = y_val.values
    # Add targets to train and val
    x_train = (x_train[0], x_train[1], x_train[2], y_train)
    x_val = (x_val[0], x_val[1], x_val[2], y_val)
    bert_model = build_bert_model(bert_layer, max_len = 70)
    checkpoint = tf.keras.callbacks.ModelCheckpoint(f'Bert_{SEED}.h5', 
                                                    monitor = 'val_loss', 
                                                    verbose = VERBOSE, 
                                                    save_best_only = True,
                                                    save_weights_only = True, 
                                                    mode = 'min')
    history = bert_model.fit(x_train, y_train,
                             validation_data = (x_val, y_val),
                             epochs = EPOCHS, 
                             callbacks = [checkpoint],
                             batch_size = BATCH_SIZE,
                             verbose = VERBOSE)
    
    

df, N_CLASSES, x_train, x_val, y_train, y_val = read_and_preprocess()
load_train_and_evaluate(x_train, x_val, y_train, y_val)
# Out:
# We have 11014 classes
# <class 'bytes'>
# 2023-04-06 00:16:29.674789: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [?,70]
# 	 [[{{node inputs}}]]
# 2023-04-06 00:16:29.674962: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [?,70]
# 	 [[{{node inputs_1}}]]
# 2023-04-06 00:16:30.015216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype int32 and shape [?,70]
# 	 [[{{node Placeholder}}]]
# 2023-04-06 00:16:30.015358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder_1' with dtype int32 and shape [?,70]
# 	 [[{{node Placeholder_1}}]]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/25
# 2023-04-06 00:16:30.707585: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [?,70]
# 	 [[{{node inputs}}]]
# 2023-04-06 00:16:30.707736: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [?,70]
# 	 [[{{node inputs_1}}]]
# 2023-04-06 00:16:41.593193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_3' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_3}}]]
# 2023-04-06 00:16:41.593501: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_4' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_4}}]]
# 2023-04-06 00:16:41.593605: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_5' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_5}}]]
# 2023-04-06 00:16:41.593694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_6' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_6}}]]
# 2023-04-06 00:16:41.593792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_7' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_7}}]]
# 2023-04-06 00:16:41.593885: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_8' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_8}}]]
# 2023-04-06 00:16:41.593979: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_9' with dtype float and shape [1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_9}}]]
# 2023-04-06 00:16:41.594072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_10' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_10}}]]
# 2023-04-06 00:16:41.594165: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_11' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_11}}]]
# 2023-04-06 00:16:41.594257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_12' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_12}}]]
# 2023-04-06 00:16:41.594349: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_13' with dtype float and shape [1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_13}}]]
# 2023-04-06 00:16:41.594440: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_14' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_14}}]]
# 2023-04-06 00:16:41.594532: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_15' with dtype float
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_15}}]]
# 2023-04-06 00:16:41.594624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_16' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_16}}]]
# 2023-04-06 00:16:41.594715: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_17' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_17}}]]
# 2023-04-06 00:16:41.594806: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_18' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_18}}]]
# 2023-04-06 00:16:41.594955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_19' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_19}}]]
# 2023-04-06 00:16:41.595061: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_20' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_20}}]]
# 2023-04-06 00:16:41.595156: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_21' with dtype float and shape [1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_21}}]]
# 2023-04-06 00:16:41.595248: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_22' with dtype float and shape [?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_22}}]]
# 2023-04-06 00:16:41.595339: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_25' with dtype float and shape [?,?,4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_25}}]]
# 2023-04-06 00:16:41.595430: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_26' with dtype float and shape [?,?,4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_26}}]]
# 2023-04-06 00:16:41.595521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_27' with dtype float and shape [?,?,4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_27}}]]
# 2023-04-06 00:16:41.595613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_28' with dtype float
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_28}}]]
# 2023-04-06 00:16:41.595703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_29' with dtype float and shape [?,?,4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_29}}]]
# 2023-04-06 00:16:41.595794: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_30' with dtype float
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_30}}]]
# 2023-04-06 00:16:41.595884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_31' with dtype float and shape [?,?,4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_31}}]]
# 2023-04-06 00:16:41.595974: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_32' with dtype float
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_32}}]]
# 2023-04-06 00:16:41.596063: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_33' with dtype float and shape [?,?,4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_33}}]]
# 2023-04-06 00:16:41.596153: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_34' with dtype float and shape [?,?,4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_34}}]]
# 2023-04-06 00:16:41.596243: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_35' with dtype float
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_35}}]]
# 2023-04-06 00:16:41.596333: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_36' with dtype float and shape [?,?,4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_36}}]]
# 2023-04-06 00:16:41.596422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_37' with dtype float
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_37}}]]
# 2023-04-06 00:16:41.596512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_38' with dtype float and shape [?,?,4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_38}}]]
# 2023-04-06 00:16:41.596601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_39' with dtype float and shape [4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_39}}]]
# 2023-04-06 00:16:41.596690: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_40' with dtype float and shape [?,4096]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_40}}]]
# 2023-04-06 00:16:41.596781: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_43' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_43}}]]
# 2023-04-06 00:16:41.596870: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_44' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_44}}]]
# 2023-04-06 00:16:41.596960: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_45' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_45}}]]
# 2023-04-06 00:16:41.597050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_46' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_46}}]]
# 2023-04-06 00:16:41.597140: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_47' with dtype float and shape [1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_47}}]]
# 2023-04-06 00:16:41.597230: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_48' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_48}}]]
# 2023-04-06 00:16:41.597319: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_49' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_49}}]]
# 2023-04-06 00:16:41.597407: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_50' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_50}}]]
# 2023-04-06 00:16:41.597496: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_51' with dtype float and shape [1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_51}}]]
# 2023-04-06 00:16:41.597585: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_52' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_52}}]]
# 2023-04-06 00:16:41.597675: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_53' with dtype float
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_53}}]]
# 2023-04-06 00:16:41.597766: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_54' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_54}}]]
# 2023-04-06 00:16:41.597856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_55' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_55}}]]
# 2023-04-06 00:16:41.597946: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_56' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_56}}]]
# 2023-04-06 00:16:41.598035: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_57' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_57}}]]
# 2023-04-06 00:16:41.598124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_58' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_58}}]]
# 2023-04-06 00:16:41.598214: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_59' with dtype float and shape [1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_59}}]]
# 2023-04-06 00:16:41.598302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_60' with dtype float and shape [?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_60}}]]
# 2023-04-06 00:16:41.598392: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_63' with dtype float and shape [?,?,16,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_63}}]]
# 2023-04-06 00:16:41.598481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_64' with dtype int32 and shape [4]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_64}}]]
# 2023-04-06 00:16:41.598571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_65' with dtype float and shape [?,16,?,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_65}}]]
# 2023-04-06 00:16:41.598661: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_66' with dtype float and shape [?,16,?,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_66}}]]
# 2023-04-06 00:16:41.598751: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_67' with dtype float and shape [?,16,?,?]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_67}}]]
# 2023-04-06 00:16:41.598841: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_68' with dtype float and shape [?,16,?,?]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_68}}]]
# 2023-04-06 00:16:41.598930: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_69' with dtype float and shape [?,16,?,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_69}}]]
# 2023-04-06 00:16:41.599036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_70' with dtype int32 and shape [4]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_70}}]]
# 2023-04-06 00:16:41.599127: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_72' with dtype float and shape [?,?,16,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_72}}]]
# 2023-04-06 00:16:41.599218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_73' with dtype float and shape [16,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_73}}]]
# 2023-04-06 00:16:41.599307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_74' with dtype float and shape [?,16,?,?]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_74}}]]
# 2023-04-06 00:16:41.599396: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_75' with dtype float and shape [?,1,?,?]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_75}}]]
# 2023-04-06 00:16:41.599485: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_76' with dtype float and shape [?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_76}}]]
# 2023-04-06 00:16:41.599574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_77' with dtype float and shape [?,16,?,?]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_77}}]]
# 2023-04-06 00:16:41.599662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_78' with dtype float
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_78}}]]
# 2023-04-06 00:16:41.599752: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_81' with dtype int32 and shape [4]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_81}}]]
# 2023-04-06 00:16:41.599845: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_82' with dtype float and shape [?,16,?,?]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_82}}]]
# 2023-04-06 00:16:41.599936: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_83' with dtype float and shape [?,16,64,?]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_83}}]]
# 2023-04-06 00:16:41.600026: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_84' with dtype float and shape [?,16,?,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_84}}]]
# 2023-04-06 00:16:41.600117: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_85' with dtype float and shape [?,16,?,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_85}}]]
# 2023-04-06 00:16:41.600207: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_86' with dtype float and shape [?,16,64,?]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_86}}]]
# 2023-04-06 00:16:41.600296: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_87' with dtype int32 and shape [4]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_87}}]]
# 2023-04-06 00:16:41.600385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_88' with dtype int32 and shape [4]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_88}}]]
# 2023-04-06 00:16:41.600475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_89' with dtype float and shape [?,?,16,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_89}}]]
# 2023-04-06 00:16:41.600564: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_90' with dtype float and shape [16,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_90}}]]
# 2023-04-06 00:16:41.600654: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_91' with dtype float and shape [?,?,16,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_91}}]]
# 2023-04-06 00:16:41.600743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_92' with dtype float and shape [16,64]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_92}}]]
# 2023-04-06 00:16:41.600831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_93' with dtype float and shape [?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_93}}]]
# 2023-04-06 00:16:41.600920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_94' with dtype float and shape [?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_94}}]]
# 2023-04-06 00:16:41.601008: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_99' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_99}}]]
# 2023-04-06 00:16:41.601097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_100' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_100}}]]
# 2023-04-06 00:16:41.601186: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_101' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_101}}]]
# 2023-04-06 00:16:41.601276: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_102' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_102}}]]
# 2023-04-06 00:16:41.601367: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_103' with dtype float and shape [1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_103}}]]
# 2023-04-06 00:16:41.601456: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_104' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_104}}]]
# 2023-04-06 00:16:41.601545: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_105' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_105}}]]
# 2023-04-06 00:16:41.601634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_106' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_106}}]]
# 2023-04-06 00:16:41.601723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_107' with dtype float and shape [1024]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_107}}]]
# 2023-04-06 00:16:41.601812: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_108' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_model/StatefulPartitionedCall_grad/bert_model/StatefulPartitionedCall_108}}]]
# ...
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2243}}]]
# 2023-04-06 00:16:45.477691: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2244' with dtype float and shape [?,16,?,?]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2244}}]]
# 2023-04-06 00:16:45.477776: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2245' with dtype float and shape [?,16,64,?]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2245}}]]
# 2023-04-06 00:16:45.477863: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2246' with dtype float and shape [?,16,?,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2246}}]]
# 2023-04-06 00:16:45.477950: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2247' with dtype float and shape [?,16,?,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2247}}]]
# 2023-04-06 00:16:45.478036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2248' with dtype float and shape [?,16,64,?]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2248}}]]
# 2023-04-06 00:16:45.478122: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2249' with dtype int32 and shape [4]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2249}}]]
# 2023-04-06 00:16:45.478207: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2250' with dtype int32 and shape [4]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2250}}]]
# 2023-04-06 00:16:45.478293: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2251' with dtype float and shape [?,?,16,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2251}}]]
# 2023-04-06 00:16:45.478379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2252' with dtype float and shape [16,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2252}}]]
# 2023-04-06 00:16:45.478464: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2253' with dtype float and shape [?,?,16,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2253}}]]
# 2023-04-06 00:16:45.478550: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2254' with dtype float and shape [16,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2254}}]]
# 2023-04-06 00:16:45.478635: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2255' with dtype float and shape [?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2255}}]]
# 2023-04-06 00:16:45.478722: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2256' with dtype float and shape [?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2256}}]]
# 2023-04-06 00:16:45.478807: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2261' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2261}}]]
# 2023-04-06 00:16:45.478893: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2262' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2262}}]]
# 2023-04-06 00:16:45.478995: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2263' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2263}}]]
# 2023-04-06 00:16:45.479087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2264' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2264}}]]
# 2023-04-06 00:16:45.479174: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2265' with dtype float and shape [1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2265}}]]
# 2023-04-06 00:16:45.479260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2266' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2266}}]]
# 2023-04-06 00:16:45.479345: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2267' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2267}}]]
# 2023-04-06 00:16:45.479430: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2268' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2268}}]]
# 2023-04-06 00:16:45.479515: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2269' with dtype float and shape [1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2269}}]]
# 2023-04-06 00:16:45.479600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2270' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2270}}]]
# 2023-04-06 00:16:45.479686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2271' with dtype float
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2271}}]]
# 2023-04-06 00:16:45.479772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2272' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2272}}]]
# 2023-04-06 00:16:45.479858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2273' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2273}}]]
# 2023-04-06 00:16:45.479944: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2274' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2274}}]]
# 2023-04-06 00:16:45.480029: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2275' with dtype float and shape [1,?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2275}}]]
# 2023-04-06 00:16:45.480114: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2276' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2276}}]]
# 2023-04-06 00:16:45.480199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2277' with dtype float and shape [?,?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2277}}]]
# 2023-04-06 00:16:45.480285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2278' with dtype float and shape [?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2278}}]]
# 2023-04-06 00:16:45.480370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2279' with dtype float and shape [?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2279}}]]
# 2023-04-06 00:16:45.480456: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2280' with dtype float and shape [?,1024]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2280}}]]
# 2023-04-06 00:16:45.480542: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2281' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2281}}]]
# 2023-04-06 00:16:45.480627: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2285' with dtype int32 and shape [?]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2285}}]]
# 533/718 [=====================>........] - ETA: 45:08 - loss: 18.2264 - sparse_categorical_accuracy: 0.0000e+00
